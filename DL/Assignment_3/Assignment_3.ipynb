# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D, Flatten ,Dropout,MaxPooling2D
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# 0 – T-shirt/top 1 – Trouser 2 – Pullover 3 – Dress 4 – Coat 5 – Sandal 6 – Shirt 7 – Sneaker 8 – Bag 9 – Ankle boot

# %%
train_df = pd.read_csv('fashion-mnist_train.csv')
test_df = pd.read_csv('fashion-mnist_test.csv')

# %%
train_df.head()

# %%
test_df.head()

# %%
train_df['label'].unique()

# %%
# Check for missing values in the training and test datasets
print("Missing values in training dataset:\n", train_df.isnull().sum())
print("\nMissing values in test dataset:\n", test_df.isnull().sum())

# iloc is used to select specific rows and columns from a DataFrame based on their integer position.
x_train = train_df.iloc[:,1:].values
y_train = train_df.iloc[:,0].values

x_test = test_df.iloc[:,1:].values
y_test = test_df.iloc[:,0].values

# %%
# Normalize the pixel values of the images to be between 0 and 1 by dividing by 255.0.
x_train = x_train/255.0
x_test = x_test/255.0

# %%
# Reshape the data to have a single channel (grayscale) for the convolutional layers.
# The reshape function is used to change the shape of the data 
# from (num_samples, 784) to (num_samples, 28, 28, 1),
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# %%
# Convert the labels to one-hot encoded vectors using the to_categorical function from Keras.
y_train_cat = to_categorical(y_train,10)
y_test_cat = to_categorical(y_test,10)

# %%
model = Sequential()

# The first convolutional layer has 32 filters, a kernel size of (3,3), and uses the ReLU activation function.
# The input shape is specified as (28,28,1) since the images are 28x28 pixels and have a single channel (grayscale).
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(MaxPooling2D(2,2))

# The second convolutional layer has 64 filters and the same kernel size and activation function.
# MaxPooling2D layers are added after each convolutional layer to reduce the spatial dimensions of the feature maps.
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))

# The Flatten layer is used to convert the 2D feature maps into a 1D vector, 
# which can be fed into the fully connected layers.
model.add(Flatten())

# The first fully connected layer has 128 units and uses the ReLU activation function.
# A Dropout layer is added after the first fully connected layer to prevent overfitting 
# by randomly setting a fraction of the input units to 0 during training.
# The second fully connected layer has 10 units (one for each class) and 
# uses the softmax activation function to output probabilities for each class.
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10,activation='softmax'))

model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()

# %%
# The model is trained for 10 epochs with a batch size of 64, 
# and 10% of the training data is used for validation.
history = model.fit(
    x_train,y_train_cat,
    epochs=10,
    batch_size=64,
    validation_split=0.1
)

# %%
plt.plot(history.history['accuracy'], label="Training Accuracy")
plt.plot(history.history['val_accuracy'], label="Validation Accuracy")
plt.xlabel('Epochs')
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
test_loss,test_accuracy= model.evaluate(x_test,y_test_cat)
print("Accuracy : ",test_accuracy)

# %%
y_pred = np.argmax(model.predict(x_test),axis=1)

# %%
print("classification report\n")
print(classification_report(y_test,y_pred))

# %%
import matplotlib.pyplot as plt
labels = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
          'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,4))
for i in range(5):
    plt.subplot(1,5,i+1)
    plt.imshow(x_test[i].reshape(28,28), cmap='gray')
    plt.title(f"True: {labels[y_test[i]]}\nPred: {labels[y_pred[i]]}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 1. What is the use of the convolution layer in CNN?
#
# The convolution layer is used to automatically extract important features from images such as edges, textures, patterns, and shapes. It applies filters (kernels) on the input image to detect spatial features.
#
# ## Key Points
# - Performs feature extraction
# - Reduces manual feature engineering
# - Detects local patterns in images
# - Preserves spatial relationships
#
# ---
#
# # 2. What are the advantages of using CNN over DNN?
#
# CNN has several advantages over traditional Deep Neural Networks (DNN):
#
# - CNN automatically extracts features from images.
# - Requires fewer parameters because of parameter sharing.
# - Better at handling image and spatial data.
# - Reduces overfitting compared to fully connected networks.
# - More computationally efficient.
# - Captures local image patterns effectively.
#
# ---
#
# # 3. Why is CNN preferred over ANN for image data?
#
# CNN is preferred because images contain spatial information such as neighboring pixels and patterns. CNN can preserve this spatial relationship using convolution and pooling operations, whereas ANN converts images into flat vectors and loses spatial structure.
#
# ## Reasons
# - Better feature extraction
# - Lower number of parameters
# - Handles large images efficiently
# - Detects edges, textures, and shapes automatically
#
# ---
#
# # 4. How would you visualize features of CNN in an image classification task?
#
# CNN features can be visualized using:
#
# - Feature maps / activation maps
# - Filters / kernels visualization
# - Heatmaps
# - Grad-CAM visualization
#
# Visualization helps understand:
#
# - Which regions the CNN focuses on
# - What patterns are learned by different layers
# - Model interpretability
#
# Early layers learn edges and textures, while deeper layers learn complex patterns and object parts.
#
# ---
#
# # 5. What do you understand about shared weights in CNN?
#
# In CNN, the same filter (kernel) weights are used across the entire image.
#
# This means:
#
# - One filter scans the whole image.
# - Same weights detect the same feature at different locations.
# - Reduces the number of trainable parameters.
#
# ## Example
# A filter detecting edges can detect edges anywhere in the image.
#
# ---
#
# # 6. Explain the role of a fully connected (FC) layer in CNN.
#
# The Fully Connected (FC) layer is used at the end of CNN for classification.
#
# ## Role of FC layer
# - Takes extracted features from convolution layers
# - Combines learned features
# - Produces final output probabilities
# - Performs classification
#
# ## Example
# In Fashion MNIST, FC layer predicts categories like:
# - Shirt
# - Shoe
# - Bag
# - Dress
#
# ---
#
# # 7. What is the importance of parameter sharing?
#
# Parameter sharing means using the same filter weights across different parts of the image.
#
# ## Importance
# - Reduces memory usage
# - Reduces computational cost
# - Decreases number of parameters
# - Improves generalization
# - Helps detect features regardless of location
#
# Without parameter sharing, CNN would become very large and inefficient.
#
# ---
#
# # 8. Explain the different types of Pooling.
#
# Pooling is used to reduce spatial dimensions of feature maps.
#
# # Types of Pooling
#
# ## 1. Max Pooling
# - Selects maximum value from pooling region
# - Most commonly used
# - Keeps important features
#
# ### Example
# From:
# [1 5]
# [2 3]
#
# ## 2. Average Pooling
#
# * Computes average value of pooling region
# * Smoothens feature maps
#
# ---
#
# ## 3. Global Average Pooling
#
# * Takes average of entire feature map
# * Reduces parameters significantly
#
# ---
#
# # Importance of Pooling
#
# * Reduces computation
# * Controls overfitting
# * Reduces feature map size
# * Improves translation invariance
#
# ```

# %% [markdown]
# # Basic Questions
#
# ## 1. What is CNN?
#
# CNN (Convolutional Neural Network) is a deep learning model mainly used for image processing and image classification tasks. It automatically extracts features from images using convolution layers.
#
# ---
#
# ## 2. What is Fashion MNIST dataset?
#
# Fashion MNIST is a dataset of grayscale clothing images used for image classification. It contains 28×28 pixel images of fashion items like shoes, shirts, bags, and dresses.
#
# ---
#
# ## 3. How many classes are present in Fashion MNIST?
#
# Fashion MNIST contains 10 classes:
#
# * T-shirt/top
# * Trouser
# * Pullover
# * Dress
# * Coat
# * Sandal
# * Shirt
# * Sneaker
# * Bag
# * Ankle boot
#
# ---
#
# ## 4. Difference between MNIST and Fashion MNIST?
#
# | MNIST            | Fashion MNIST        |
# | ---------------- | -------------------- |
# | Digit images     | Clothing images      |
# | Easier dataset   | More complex dataset |
# | Digits 0–9       | Fashion categories   |
# | Simpler patterns | Real-world patterns  |
#
# ---
#
# ## 5. Why is normalization used?
#
# Normalization scales pixel values to a smaller range (usually 0 to 1). It helps:
#
# * Faster training
# * Better convergence
# * Stable gradient updates
#
# Example:
#
# ```python id="x0hvw8"
# x_train = x_train / 255.0
# ```
#
# ---
#
# ## 6. Why do we reshape image data?
#
# CNN expects image data in 3D/4D format:
#
# ```text id="2f3vpr"
# (height, width, channels)
# ```
#
# For grayscale images:
#
# ```python id="cr5vh0"
# (28,28,1)
# ```
#
# Reshaping adds the channel dimension.
#
# ---
#
# ## 7. What is image classification?
#
# Image classification is the task of assigning a label/category to an image.
#
# Example:
#
# ```text id="2yr8pq"
# Input image → Shoe
# ```
#
# ---
#
# ## 8. What is a kernel/filter?
#
# A kernel/filter is a small matrix used in convolution to detect features like:
#
# * edges
# * textures
# * patterns
#
# Example:
#
# ```text id="q0u0of"
# 3×3 filter
# ```
#
# ---
#
# ## 9. What is stride in CNN?
#
# Stride is the number of pixels the filter moves during convolution.
#
# * Stride = 1 → moves one pixel
# * Larger stride → smaller output feature map
#
# ---
#
# ## 10. What is padding?
#
# Padding adds extra pixels around image borders.
#
# Purpose:
#
# * Preserve image size
# * Prevent information loss at edges
#
# Types:
#
# * Valid padding
# * Same padding
#
# ---
#
# # Intermediate Viva Questions
#
# ## 11. What happens after convolution operation?
#
# After convolution:
#
# * Feature maps are generated
# * Activation function like ReLU is applied
# * Important features are extracted
#
# ---
#
# ## 12. Why is ReLU used in CNN?
#
# ReLU introduces non-linearity.
#
# Formula:
#
# ```text id="b1nlv9"
# f(x)=max(0,x)
# ```
#
# Advantages:
#
# * Faster training
# * Reduces vanishing gradient problem
#
# ---
#
# ## 13. What is feature extraction?
#
# Feature extraction means automatically identifying important image patterns such as:
#
# * edges
# * corners
# * textures
# * shapes
#
# ---
#
# ## 14. What is feature map?
#
# Feature map is the output generated after applying a filter to an image.
#
# It represents detected features.
#
# ---
#
# ## 15. What is flatten layer?
#
# Flatten converts 2D feature maps into a 1D vector before passing data to fully connected layers.
#
# Example:
#
# ```text id="m4q6v5"
# 28×28 → 784
# ```
#
# ---
#
# ## 16. Why is softmax used in output layer?
#
# Softmax converts outputs into probability values between 0 and 1.
#
# Used for:
#
# ```text id="c24of9"
# Multi-class classification
# ```
#
# ---
#
# ## 17. Explain categorical cross entropy.
#
# Categorical Cross Entropy is a loss function used in multi-class classification problems.
#
# It measures difference between:
#
# * actual labels
# * predicted probabilities
#
# ---
#
# ## 18. What optimizer did you use?
#
# Commonly used optimizer:
#
# ```text id="fymjfw"
# Adam Optimizer
# ```
#
# It updates model weights efficiently during training.
#
# ---
#
# ## 19. Why is Adam optimizer popular?
#
# Advantages:
#
# * Fast convergence
# * Adaptive learning rate
# * Works well for deep learning models
# * Combines RMSProp and Momentum
#
# ---
#
# ## 20. What is batch size?
#
# Batch size is the number of training samples processed before updating weights.
#
# Example:
#
# ```text id="h8pq4z"
# Batch size = 32
# ```
#
# means 32 images processed together.
#
# ---
#
# ## 21. What is epoch?
#
# One complete pass of the entire training dataset through the model.
#
# ---
#
# ## 22. What is dropout?
#
# Dropout randomly disables neurons during training to reduce overfitting.
#
# Example:
#
# ```python id="tjlwm9"
# Dropout(0.2)
# ```
#
# means 20% neurons are dropped.
#
# ---
#
# ## 23. What is overfitting?
#
# Overfitting occurs when model performs very well on training data but poorly on new unseen data.
#
# ---
#
# ## 24. Difference between training and validation accuracy?
#
# | Training Accuracy         | Validation Accuracy                |
# | ------------------------- | ---------------------------------- |
# | Accuracy on training data | Accuracy on unseen validation data |
# | Usually higher            | Shows generalization ability       |
#
# ---
#
# ## 25. What is loss function?
#
# Loss function measures prediction error of the model.
#
# Lower loss means better predictions.
#
# ---
#
# # Advanced Viva Questions
#
# ## 26. Explain forward propagation in CNN.
#
# Forward propagation is the process where:
#
# * Input image passes through layers
# * Features are extracted
# * Predictions are generated
#
# Flow:
#
# ```text id="czk9pq"
# Input → Convolution → ReLU → Pooling → FC Layer → Output
# ```
#
# ---
#
# ## 27. Explain backpropagation in CNN.
#
# Backpropagation updates weights using gradients calculated from loss.
#
# Steps:
#
# * Compute loss
# * Calculate gradients
# * Update weights using optimizer
#
# ---
#
# ## 28. What are trainable parameters?
#
# Trainable parameters are weights and biases learned during training.
#
# CNN learns these automatically.
#
# ---
#
# ## 29. Why are CNNs computationally efficient?
#
# Reasons:
#
# * Parameter sharing
# * Sparse connectivity
# * Pooling reduces dimensions
#
# This reduces computation and memory usage.
#
# ---
#
# ## 30. Difference between CNN and RNN?
#
# | CNN                   | RNN                      |
# | --------------------- | ------------------------ |
# | Used for images       | Used for sequential data |
# | Spatial data          | Time-series/text         |
# | Convolution operation | Recurrent connections    |
#
# ---
#
# ## 31. What is transfer learning?
#
# Transfer learning uses a pre-trained model on a new task.
#
# Example:
#
# * Using ResNet trained on ImageNet.
#
# Benefits:
#
# * Faster training
# * Better accuracy
#
# ---
#
# ## 32. What is data augmentation?
#
# Data augmentation artificially increases dataset size using:
#
# * rotation
# * flipping
# * zooming
# * shifting
#
# Helps reduce overfitting.
#
# ---
#
# ## 33. Why does CNN perform well on image data?
#
# CNN preserves spatial relationships and automatically extracts image features efficiently.
#
# ---
#
# ## 34. What are activation maps?
#
# Activation maps show which image regions activate neurons strongly.
#
# They help visualize learned features.
#
# ---
#
# ## 35. Explain vanishing gradient problem.
#
# In deep networks, gradients become extremely small during backpropagation, causing slow or failed learning.
#
# Common in:
#
# * Deep neural networks
# * Simple RNNs
#
# ---
#
# ## 36. What is the role of optimizer in CNN?
#
# Optimizer updates model weights to minimize loss function.
#
# Example:
#
# * Adam
# * SGD
# * RMSProp
#
# ---
#
# ## 37. Difference between sigmoid and softmax?
#
# | Sigmoid                          | Softmax                         |
# | -------------------------------- | ------------------------------- |
# | Binary classification            | Multi-class classification      |
# | Output independent probabilities | Output probability distribution |
#
# ---
#
# ## 38. What evaluation metrics are used in classification?
#
# Common metrics:
#
# * Accuracy
# * Precision
# * Recall
# * F1-score
# * Confusion Matrix
#
# ---
#
# ## 39. What is confusion matrix?
#
# Confusion matrix shows:
#
# * Correct predictions
# * Incorrect predictions
#
# It contains:
#
# * TP
# * TN
# * FP
# * FN
#
# ---
#
# ## 40. What is precision, recall, and F1-score?
#
# ### Precision
#
# Measures correctness of positive predictions.
#
# Formula:
#
# ```text id="0q9fs9"
# TP / (TP + FP)
# ```
#
# ---
#
# ### Recall
#
# Measures how many actual positives are correctly identified.
#
# Formula:
#
# ```text id="2vsxvy"
# TP / (TP + FN)
# ```
#
# ---
#
# ### F1-score
#
# Harmonic mean of precision and recall.
#
# Used when dataset is imbalanced.
